# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
from model import ObjectsAsPoints, HourglassModule

# %%
inputs = tf.zeros((1, 256, 256, 3))
# outputs = HourglassModule(inputs)
model = ObjectsAsPoints()
model.summary()
# Out:
# Model: "object_as_points"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_1459 (Conv2D)            (None, 128, 128, 128 18816       input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1369 (Batch (None, 128, 128, 128 512         conv2d_1459[0][0]
# __________________________________________________________________________________________________
# re_lu_1261 (ReLU)               (None, 128, 128, 128 0           batch_normalization_1369[0][0]
# __________________________________________________________________________________________________
# ...
